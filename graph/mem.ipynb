# %%
import matplotlib.pyplot as plt
import numpy as np

models = ["LeNet", "ResNet18", "ResNet34", "ResNet101", "ResNet152", "ResNet269"]

# 단위: MB (FP32 파라미터 기준)
# max_layer_mem = [0.05, 5.1, 7.3, 10.5, 12.3, 16.4]
total_mem     = [0.24, 46.8, 87.2, 178.0, 240.8, 408.0]

x = np.arange(len(models))
bar_width = 0.35

fig, ax = plt.subplots(figsize=(10, 7))
# rects1 = ax.bar(x - bar_width/2, max_layer_mem, bar_width, label='DL', color='#1f77b4')
rects2 = ax.bar(x, total_mem, bar_width, label='Weights', color='#ff7f0e')

# 🔴 수평 점선 (TEE 메모리 경계선)
ax.axhline(y=128, color='red', linestyle='--', linewidth=1.5, label='TEE Memory (128MB)')

ax.set_xlabel('Model', fontsize=13)
ax.set_ylabel('Memory (MB)', fontsize=13)
# ax.set_title('Model vs Memory Usage (FP32 Params)', fontsize=15)
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=45, ha='right')
ax.legend(fontsize=12)
ax.grid(axis='y', linestyle='--', alpha=0.6)

for rects in [rects2]:
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x()+ rect.get_width()/2., height + (height*0.03 if height>1 else 0.05),
                f'{height:.1f}', ha='center', va='bottom', fontsize=9)
ax.set_ylim(0,450)
plt.tight_layout()
plt.show()
# Out:
#   Cell In[14], line 18
#     ax.axhline(y=128, color='red', linestyle='--', linewidth=1.5, label='TEE Memory (128MB)')import matplotlib.pyplot as plt
#                                                                                              ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ["LeNet", "ResNet18", "ResNet34", "ResNet101", "ResNet152", "ResNet269"]

# 단위: MB (FP32 파라미터 기준)
total_mem = [0.24, 46.8, 87.2, 178.0, 240.8, 408.0]

x = np.arange(len(models))
bar_width = 0.35

# ✅ 🔧 전체 폰트 크기 기본 설정 (먼저 실행!)
plt.rcParams.update({
    'font.size': 20,          # 기본 폰트 크기
    'axes.titlesize': 24,     # 제목 크기
    'axes.labelsize': 20,     # 축 라벨 크기
    'xtick.labelsize': 15,    # X축 눈금
    'ytick.labelsize': 15,    # Y축 눈금
    'legend.fontsize': 18,    # 범례
})

# ✅ 그래프 생성은 그다음
fig, ax = plt.subplots(figsize=(10, 7))
rects2 = ax.bar(x, total_mem, bar_width, label='Weights', color='#ff7f0e')

# 🔴 수평 점선 (TEE 메모리 경계선)
ax.axhline(y=128, color='red', linestyle='--', linewidth=2, label='TEE Memory (128MB)')

# 라벨 설정
ax.set_ylabel('Memory (MB)', labelpad=10)
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=45, ha='right')
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.6)

# 막대 위에 수치 표기
for rect in rects2:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2., height + (height*0.03 if height > 1 else 0.05),
            f'{height:.1f}', ha='center', va='bottom', fontsize=16)

ax.set_ylim(0, 450)
plt.tight_layout()
plt.show()
