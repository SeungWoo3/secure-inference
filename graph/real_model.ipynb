# %%
import pandas as pd

# 📁 파일 경로
file_path_1 = "/home/avees/tee/output/component_with_edited/output_pp0-2_1022_1445.csv"
file_path_2 = "/home/avees/tee/output/component_with_edited/output_pp999-999_1022_1445.csv"

# 📖 CSV 파일 읽기
df1 = pd.read_csv(file_path_1)
df2 = pd.read_csv(file_path_2)

# ✅ 파일별 기본 정보 출력
print("✅ 첫 번째 파일 요약 (pp0-2):")
print(df1.head(), "\n")
print("컬럼:", df1.columns.tolist())
print("크기:", df1.shape, "\n")

print("✅ 두 번째 파일 요약 (pp999-999):")
print(df2.head(), "\n")
print("컬럼:", df2.columns.tolist())
print("크기:", df2.shape)
# Out:
# ✅ 첫 번째 파일 요약 (pp0-2):
#       IN[0]  INFER[0-2]    OUT[2]  TEE[0-2]  Layer[3]  Layer[4]  Layer[5]  \
# 0  0.129441    9.113830  0.103648  9.352583  0.013281  0.049248  0.000768
# 1  0.150433    1.518827  0.093953  1.770285  0.008960  0.049505  0.000608
# 2  0.158914    1.501195  0.074817  1.741742  0.005920  0.048384  0.000608
# 3  0.159393    1.540492  0.107073  1.814542  0.005856  0.048160  0.000608
# 4  0.160705    1.498380  0.074432  1.739821  0.014336  0.050465  0.000544
#
#    Layer[6]  Layer[7]  Layer[8]  Layer[9]  Layer[10]  classifier
# 0  0.013472  0.000384  0.001600  0.002080   0.000640    9.439240
# 1  0.014304  0.000640  0.001728  0.001376   0.000384    1.852814
# 2  0.014176  0.000608  0.001792  0.001600   0.000352    1.819982
# 3  0.014080  0.000352  0.001728  0.001344   0.000384    1.891566
# 4  0.014304  0.000576  0.001696  0.001472   0.000352    1.828846
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 📁 파일 경로
file1 = "/home/avees/tee/output/component_with_edited/output_pp0-2_1022_1445.csv"
file2 = "/home/avees/tee/output/component_with_edited/output_pp999-999_1022_1445.csv"

# 📖 CSV 읽기
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# 🚫 상위 5행 제거
df1 = df1.iloc[5:]
df2 = df2.iloc[5:]

# 📊 평균 계산
mean1 = df1.mean()
mean2 = df2.mean()

# ✅ 첫 번째 파일 구성
in_val = mean1["IN[0]"]
infer_val = mean1["INFER[0-2]"]
out_val = mean1["OUT[2]"]
layer_3_10_val = mean1[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ✅ 두 번째 파일 구성
layer_0_2_val = mean2[[f"Layer[{i}]" for i in range(0, 3)]].sum()
layer_3_10_val_2 = mean2[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ==============================
# 📈 그래프 그리기
# ==============================
fig, ax = plt.subplots(figsize=(8, 6))

# x축 위치
x = np.arange(2)

# 첫 번째 파일 (왼쪽 막대)
ax.bar(x[0], in_val, label="IN[0]", color="#4C72B0")
ax.bar(x[0], infer_val, bottom=in_val, label="INFER[0-2]", color="#55A868")
ax.bar(x[0], out_val, bottom=in_val + infer_val, label="OUT[2]", color="#C44E52")
ax.bar(x[0], layer_3_10_val, bottom=in_val + infer_val + out_val, label="Layer[3-10]", color="#8172B2")

# 두 번째 파일 (오른쪽 막대)
ax.bar(x[1], layer_0_2_val, label="Layer[0-2]", color="#CCB974")
ax.bar(x[1], layer_3_10_val_2, bottom=layer_0_2_val, label="Layer[3-10] (2nd)", color="#64B5CD")

# x축 라벨 및 꾸미기
ax.set
# Out:
# <bound method Artist.set of <matplotlib.axes._subplots.AxesSubplot object at 0xffff8c753ca0>>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 📁 파일 경로
file1 = "/home/avees/tee/output/component_with_edited/output_pp0-2_1022_1445.csv"
file2 = "/home/avees/tee/output/component_with_edited/output_pp999-999_1022_1445.csv"

# 📖 CSV 읽기
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# 🚫 상위 5행 제거
df1 = df1.iloc[5:]
df2 = df2.iloc[5:]

# 📊 평균 계산
mean1 = df1.mean()
mean2 = df2.mean()

# ✅ 첫 번째 파일 (pp0-2)
in_val = mean1["IN[0]"]
infer_val = mean1["INFER[0-2]"]
out_val = mean1["OUT[2]"]
layer_3_10_val = mean1[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ✅ 두 번째 파일 (pp999-999)
layer_0_2_val = mean2[[f"Layer[{i}]" for i in range(0, 3)]].sum()
layer_3_10_val_2 = mean2[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ==============================
# 📈 그래프 그리기
# ==============================
fig, ax = plt.subplots(figsize=(8, 6))
x = np.arange(2)
bar_width = 0.4  # 막대 너비

# 왼쪽 막대 (pp0-2)
ax.bar(x[0], in_val, width=bar_width, label="IN[0]", color="#4C72B0")
ax.bar(x[0], infer_val, bottom=in_val, width=bar_width, label="INFER[0-2]", color="#55A868")
ax.bar(x[0], out_val, bottom=in_val + infer_val, width=bar_width, label="OUT[2]", color="#C44E52")
ax.bar(x[0], layer_3_10_val, bottom=in_val + infer_val + out_val, width=bar_width, label="Layer[3-10]", color="#8172B2")

# 오른쪽 막대 (pp999-999)
ax.bar(x[1], layer_0_2_val, width=bar_width, label="Layer[0-2]", color="#CCB974")
ax.bar(x[1], layer_3_10_val_2, bottom=layer_0_2_val, width=bar_width, label="Layer[3-10] (2nd)", color="#64B5CD")

# ==============================
# 🔗 대응 구간 연결선 (두 꼭짓점)
# ==============================
# 왼쪽 INFER[0-2] 구간
y_left_bottom = in_val
y_left_top = in_val + infer_val

# 오른쪽 Layer[0-2] 구간
y_right_bottom = 0
y_right_top = layer_0_2_val

# 선을 막대의 오른쪽끝 → 왼쪽끝으로
x_left_edge = x[0] + bar_width / 2
x_right_edge = x[1] - bar_width / 2

# 아래쪽 점선
ax.plot([x_left_edge, x_right_edge], [y_left_bottom, y_right_bottom],
        color="black", linewidth=2, linestyle="--", zorder=5)

# 위쪽 점선
ax.plot([x_left_edge, x_right_edge], [y_left_top, y_right_top],
        color="black", linewidth=2, linestyle="--", zorder=5)

# ==============================
# 꾸미기
# ==============================
ax.set_xticks(x)
ax.set_xticklabels(["pp0-2", "pp999-999"])
ax.set_ylabel("Average Time (ms)")
ax.set_title("Component-wise Average Comparison (Edge-to-Edge Connection)")
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 📁 파일 경로
file1 = "/home/avees/tee/output/component_with_edited/output_pp0-2_1022_1445.csv"
file2 = "/home/avees/tee/output/component_with_edited/output_pp999-999_1022_1445.csv"

# 📖 CSV 읽기
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# 🚫 상위 5행 제거
df1 = df1.iloc[5:]
df2 = df2.iloc[5:]

# 📊 평균 계산
mean1 = df1.mean()
mean2 = df2.mean()

# ✅ 첫 번째 파일 (pp0-2)
in_val = mean1["IN[0]"]                # 1
infer_val = mean1["INFER[0-2]"]        # 2
out_val = mean1["OUT[2]"]              # 3
layer_3_10_val = mean1[[f"Layer[{i}]" for i in range(3, 11)]].sum()  # 4

# ✅ 두 번째 파일 (pp999-999)
layer_0_2_val = mean2[[f"Layer[{i}]" for i in range(0, 3)]].sum()    # 5
layer_3_10_val_2 = mean2[[f"Layer[{i}]" for i in range(3, 11)]].sum() # 6

# ==============================
# 📈 그래프 그리기
# ==============================
fig, ax = plt.subplots(figsize=(8, 6))
x = np.arange(2)
bar_width = 0.4

# 🎨 색상 팔레트 (HSV 변형 기반, 모두 #1565C0 계열)
color_1 = "#8FA3C7"   # 블루
color_2_5 = "#9FB999" # 올리브그린
color_3 = "#C5A98B"   # 베이지
color_4_6 = "#B89DB8" # 라벤더

# 왼쪽 막대 (pp0-2)
ax.bar(x[0], in_val, width=bar_width, color=color_1, label="1. IN[0]")
ax.bar(x[0], infer_val, bottom=in_val, width=bar_width, color=color_2_5, label="2. INFER[0-2]")
ax.bar(x[0], out_val, bottom=in_val + infer_val, width=bar_width, color=color_3, label="3. OUT[2]")
ax.bar(x[0], layer_3_10_val, bottom=in_val + infer_val + out_val, width=bar_width, color=color_4_6, label="4. Layer[3-10]")

# 오른쪽 막대 (pp999-999)
ax.bar(x[1], layer_0_2_val, width=bar_width, color=color_2_5, label="5. Layer[0-2]")
ax.bar(x[1], layer_3_10_val_2, bottom=layer_0_2_val, width=bar_width, color=color_4_6, label="6. Layer[3-10] (2nd)")

# ==============================
# 🔗 대응 구간 연결선 (2 ↔ 5)
# ==============================
y_left_bottom = in_val
y_left_top = in_val + infer_val
y_right_bottom = 0
y_right_top = layer_0_2_val

x_left_edge = x[0] + bar_width / 2
x_right_edge = x[1] - bar_width / 2

# 두 꼭짓점 연결선 (2 ↔ 5)
ax.plot([x_left_edge, x_right_edge], [y_left_bottom, y_right_bottom],
        color=color_2_5, linewidth=2.5, linestyle="--", zorder=5)
ax.plot([x_left_edge, x_right_edge], [y_left_top, y_right_top],
        color=color_2_5, linewidth=2.5, linestyle="--", zorder=5)

# ==============================
# 꾸미기
# ==============================
ax.set_xticks(x)
ax.set_xticklabels(["pp0-2", "pp999-999"])
ax.set_ylabel("Average Time (ms)")
ax.set_title("Component-wise Average Comparison (Unified Blue Tone)")

# 범례 정리
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 📁 파일 경로
file1 = "/home/avees/tee/output/component_with_edited/output_pp0-2_1022_1445.csv"
file2 = "/home/avees/tee/output/component_with_edited/output_pp999-999_1022_1445.csv"

# 📖 CSV 읽기
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# 🚫 상위 5행 제거
df1 = df1.iloc[5:]
df2 = df2.iloc[5:]

# 📊 평균 계산
mean1 = df1.mean()
mean2 = df2.mean()

# ✅ 첫 번째 파일 (pp0-2)
in_val = mean1["IN[0]"]
infer_val = mean1["INFER[0-2]"]
out_val = mean1["OUT[2]"]
layer_3_10_val = mean1[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ✅ 두 번째 파일 (pp999-999)
layer_0_2_val = mean2[[f"Layer[{i}]" for i in range(0, 3)]].sum()
layer_3_10_val_2 = mean2[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ==============================
# 🎨 색상 팔레트 (Soft Tint)
color_1 = "#8FA3C7"   # 블루
color_2_5 = "#9FB999" # 올리브그린
color_3 = "#C5A98B"   # 베이지
color_4_6 = "#B89DB8" # 라벤더

# ==============================
# 🏷️ 문자열 설정 (범례 & X라벨)
legend_labels = {
    1: "REE → TEE",
    2: "Infer[1-2]",
    3: "TEE → REE",
    4: "Infer[3-11]",
    5: "Infer[1-2]",
    6: "Infer[3-11]"
}

x_labels = ["TEE Inference", "REE Inference"]

# ==============================
# 📈 그래프
# ==============================
fig, ax = plt.subplots(figsize=(8, 6))
x = np.arange(2)
bar_width = 0.4

# 왼쪽 막대 (pp0-2)
ax.bar(x[0], in_val, width=bar_width, color=color_1, edgecolor="black", linewidth=1, label=legend_labels[1])
ax.bar(x[0], infer_val, bottom=in_val, width=bar_width, color=color_2_5, edgecolor="black", linewidth=1, label=legend_labels[2])
ax.bar(x[0], out_val, bottom=in_val + infer_val, width=bar_width, color=color_3, edgecolor="black", linewidth=1, label=legend_labels[3])
ax.bar(x[0], layer_3_10_val, bottom=in_val + infer_val + out_val, width=bar_width, color=color_4_6, edgecolor="black", linewidth=1, label=legend_labels[4])

# 오른쪽 막대 (pp999-999)
ax.bar(x[1], layer_0_2_val, width=bar_width, color=color_2_5, edgecolor="black", linewidth=1, label=legend_labels[5])
ax.bar(x[1], layer_3_10_val_2, bottom=layer_0_2_val, width=bar_width, color=color_4_6, edgecolor="black", linewidth=1, label=legend_labels[6])

# 🔗 대응 구간 연결선 (2 ↔ 5)
y_left_bottom = in_val
y_left_top = in_val + infer_val
y_right_bottom = 0
y_right_top = layer_0_2_val

x_left_edge = x[0] + bar_width / 2
x_right_edge = x[1] - bar_width / 2

ax.plot([x_left_edge, x_right_edge], [y_left_bottom, y_right_bottom],
        color="#000000", linewidth=2.5, linestyle="--", zorder=5)
ax.plot([x_left_edge, x_right_edge], [y_left_top, y_right_top],
        color="#000000", linewidth=2.5, linestyle="--", zorder=5)

# ==============================
# ⚙️ 스타일
# ==============================
ax.set_xticks(x)
ax.set_xticklabels(x_labels, color="black", fontsize=12)
ax.set_ylabel("Time (ms)", color="black", fontsize=12)
ax.set_title("Inference Time Comparison (TEE vs. REE)", color="black", fontsize=13, pad=12)

# 축 및 테두리
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1)

# ✅ 범례 — 중복 제거 + 순서 유지
handles, labels = ax.get_legend_handles_labels()
unique = dict(zip(labels, handles))  # 중복 제거
ax.legend(unique.values(), unique.keys(), bbox_to_anchor=(1.05, 1), loc='upper left',
          fontsize=10, frameon=True, edgecolor="black")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 📁 파일 경로
file1 = "/home/avees/tee/output/component_with_edited/output_pp0-2_1022_1445.csv"
file2 = "/home/avees/tee/output/component_with_edited/output_pp999-999_1022_1445.csv"

# 📖 CSV 읽기
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# 🚫 상위 5행 제거
df1 = df1.iloc[5:]
df2 = df2.iloc[5:]

# 📊 평균 계산
mean1 = df1.mean()
mean2 = df2.mean()

# ✅ 첫 번째 파일 (pp0-2)
in_val = mean1["IN[0]"]
infer_val = mean1["INFER[0-2]"]
out_val = mean1["OUT[2]"]
layer_3_10_val = mean1[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ✅ 두 번째 파일 (pp999-999)
layer_0_2_val = mean2[[f"Layer[{i}]" for i in range(0, 3)]].sum()
layer_3_10_val_2 = mean2[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ==============================
# 🎨 색상 팔레트 (Soft Tint)
color_1 = "#8FA3C7"   # 블루
color_2_5 = "#9FB999" # 올리브그린
color_3 = "#C5A98B"   # 베이지
color_4_6 = "#B89DB8" # 라벤더

# ==============================
# 🏷️ 문자열 설정 (범례 & X라벨)
legend_labels = {
    1: "REE → TEE",
    2: "Infer[1-2]",
    3: "TEE → REE",
    4: "Infer[3-11]",
    5: "Infer[1-2]",
    6: "Infer[3-11]"
}

x_labels = ["Partial TEE Inference", "Baseline"]

# ==============================
# 📈 그래프
# ==============================
fig, ax = plt.subplots(figsize=(10, 7))
x = np.arange(2)
bar_width = 0.4

# 왼쪽 막대 (TEE)
ax.bar(x[0], in_val, width=bar_width, color=color_1, edgecolor="black", linewidth=1, label=legend_labels[1])
ax.bar(x[0], infer_val, bottom=in_val, width=bar_width, color=color_2_5, edgecolor="black", linewidth=1, label=legend_labels[2])
ax.bar(x[0], out_val, bottom=in_val + infer_val, width=bar_width, color=color_3, edgecolor="black", linewidth=1, label=legend_labels[3])
ax.bar(x[0], layer_3_10_val, bottom=in_val + infer_val + out_val, width=bar_width, color=color_4_6, edgecolor="black", linewidth=1, label=legend_labels[4])

# 오른쪽 막대 (REE)
ax.bar(x[1], layer_0_2_val, width=bar_width, color=color_2_5, edgecolor="black", linewidth=1, label=legend_labels[5])
ax.bar(x[1], layer_3_10_val_2, bottom=layer_0_2_val, width=bar_width, color=color_4_6, edgecolor="black", linewidth=1, label=legend_labels[6])

# 🔗 대응 구간 연결선 (2 ↔ 5)
y_left_bottom = in_val
y_left_top = in_val + infer_val
y_right_bottom = 0
y_right_top = layer_0_2_val

x_left_edge = x[0] + bar_width / 2
x_right_edge = x[1] - bar_width / 2

ax.plot([x_left_edge, x_right_edge], [y_left_bottom, y_right_bottom],
        color="#000000", linewidth=2.5, linestyle="--", zorder=5)
ax.plot([x_left_edge, x_right_edge], [y_left_top, y_right_top],
        color="#000000", linewidth=2.5, linestyle="--", zorder=5)

# ==============================
# ⚙️ 스타일
# ==============================
ax.set_xticks(x)
ax.set_xticklabels(x_labels, color="black", fontsize=12)
ax.set_ylabel("Time (ms)", color="black", fontsize=12)
ax.set_title("Inference Time Comparison (TEE vs. REE)", color="black", fontsize=13, pad=12)

# 축 및 테두리
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1)

# ✅ 범례 — 그래프 내부 (오른쪽 위)
handles, labels = ax.get_legend_handles_labels()
unique = dict(zip(labels, handles))
ax.legend(unique.values(), unique.keys(),
          loc="upper right",        # 그래프 내부 오른쪽 위
          fontsize=10,
          frameon=True,
          edgecolor="black",
          facecolor="white")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 📁 파일 경로
file1 = "/home/avees/tee/output/component_with_edited/output_pp0-2_1022_1445.csv"
file2 = "/home/avees/tee/output/component_with_edited/output_pp999-999_1022_1445.csv"

# ==============================
# 🧩 폰트 크기 설정 (먼저 지정!)
title_fontsize = 20       # 그래프 제목 (하단)
label_fontsize = 16       # y축 라벨
tick_fontsize = 16        # x축 tick
legend_fontsize = 14      # 범례 폰트

plt.rcParams.update({
    'font.size': 20,          # 기본 폰트 크기
    'axes.titlesize': 24,     # 제목 크기
    'axes.labelsize': 20,     # 축 라벨 크기
    'xtick.labelsize': 15,    # X축 눈금
    'ytick.labelsize': 15,    # Y축 눈금
    'legend.fontsize': 18,    # 범례
})

# ==============================
# 📖 CSV 읽기 및 전처리
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df1 = df1.iloc[5:]
df2 = df2.iloc[5:]
mean1 = df1.mean()
mean2 = df2.mean()

# ✅ 평균 값 추출
in_val = mean1["IN[0]"]
infer_val = mean1["INFER[0-2]"]
out_val = mean1["OUT[2]"]
layer_3_10_val = mean1[[f"Layer[{i}]" for i in range(3, 11)]].sum()
layer_0_2_val = mean2[[f"Layer[{i}]" for i in range(0, 3)]].sum()
layer_3_10_val_2 = mean2[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ==============================
# 🎨 색상 팔레트 (Soft Tint)
color_1 = "#8FA3C7"   # 블루
color_2_5 = "#9FB999" # 올리브그린
color_3 = "#C5A98B"   # 베이지
color_4_6 = "#B89DB8" # 라벤더

# ==============================
# 🏷️ 문자열 설정 (범례 & X라벨)
legend_labels = {
    1: "REE → TEE",
    2: "Infer[1-2]",
    3: "TEE → REE",
    4: "Infer[3-11]",
    5: "Infer[1-2]",
    6: "Infer[3-11]"
}

x_labels = ["Partial TEE Inference", "Baseline"]

# ==============================
# 📈 그래프
fig, ax = plt.subplots(figsize=(10, 7))
x = np.arange(2)
bar_width = 0.4

# 왼쪽 막대 (TEE)
ax.bar(x[0], in_val, width=bar_width, color=color_1, edgecolor="black", linewidth=1, label=legend_labels[1])
ax.bar(x[0], infer_val, bottom=in_val, width=bar_width, color=color_2_5, edgecolor="black", linewidth=1, label=legend_labels[2])
ax.bar(x[0], out_val, bottom=in_val + infer_val, width=bar_width, color=color_3, edgecolor="black", linewidth=1, label=legend_labels[3])
ax.bar(x[0], layer_3_10_val, bottom=in_val + infer_val + out_val, width=bar_width, color=color_4_6, edgecolor="black", linewidth=1, label=legend_labels[4])

# 오른쪽 막대 (REE)
ax.bar(x[1], layer_0_2_val, width=bar_width, color=color_2_5, edgecolor="black", linewidth=1, label=legend_labels[5])
ax.bar(x[1], layer_3_10_val_2, bottom=layer_0_2_val, width=bar_width, color=color_4_6, edgecolor="black", linewidth=1, label=legend_labels[6])

# 🔗 대응 구간 연결선 (2 ↔ 5)
y_left_bottom = in_val
y_left_top = in_val + infer_val
y_right_bottom = 0
y_right_top = layer_0_2_val
x_left_edge = x[0] + bar_width / 2
x_right_edge = x[1] - bar_width / 2
ax.plot([x_left_edge, x_right_edge], [y_left_bottom, y_right_bottom],
        color="#000000", linewidth=2.5, linestyle="--", zorder=5)
ax.plot([x_left_edge, x_right_edge], [y_left_top, y_right_top],
        color="#000000", linewidth=2.5, linestyle="--", zorder=5)

# ==============================
# ⚙️ 스타일
ax.set_xticks(x)
ax.set_xticklabels(x_labels, color="black", fontsize=tick_fontsize)
ax.set_ylabel("Time (ms)", color="black", fontsize=label_fontsize)


# 축 및 테두리
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1)

# ✅ 범례 — 그래프 내부
handles, labels = ax.get_legend_handles_labels()
unique = dict(zip(labels, handles))
ax.legend(unique.values(), unique.keys(),
          loc="upper right",
          fontsize=legend_fontsize,
          frameon=True,
          edgecolor="black",
          facecolor="white")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 📁 파일 경로
file1 = "/home/avees/tee/output/component_with_edited/output_pp0-2_1022_1445.csv"
file2 = "/home/avees/tee/output/component_with_edited/output_pp999-999_1022_1445.csv"

# ==============================
# 🧩 폰트 크기 설정
title_fontsize = 20
label_fontsize = 16
tick_fontsize = 16
legend_fontsize = 14

plt.rcParams.update({
    'font.size': 20,
    'axes.titlesize': 24,
    'axes.labelsize': 20,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'legend.fontsize': 18,
})

# ==============================
# 📖 CSV 읽기 및 전처리
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df1 = df1.iloc[5:]
df2 = df2.iloc[5:]
mean1 = df1.mean()
mean2 = df2.mean()

# ✅ 평균 값 추출
in_val = mean1["IN[0]"]
infer_val = mean1["INFER[0-2]"]
out_val = mean1["OUT[2]"]
layer_3_10_val = mean1[[f"Layer[{i}]" for i in range(3, 11)]].sum()
layer_0_2_val = mean2[[f"Layer[{i}]" for i in range(0, 3)]].sum()
layer_3_10_val_2 = mean2[[f"Layer[{i}]" for i in range(3, 11)]].sum()

# ==============================
# 🎨 색상 팔레트
color_1 = "#8FA3C7"   # 블루
color_2_5 = "#9FB999" # 올리브그린
color_3 = "#C5A98B"   # 베이지
color_4_6 = "#B89DB8" # 라벤더

# ==============================
# 🏷️ 문자열 설정
legend_labels = {
    1: "REE → TEE",
    2: "Infer[1-3]",
    3: "TEE → REE",
    4: "Infer[4-11]",
    5: "Infer[1-3]",
    6: "Infer[4-11]"
}

x_labels = ["REE-only", "REE+TEE"]  # ← 좌우 반전

# ==============================
# 📈 그래프
fig, ax = plt.subplots(figsize=(10, 7))
x = np.arange(2)
bar_width = 0.4

# 왼쪽 막대 (Baseline)
ax.bar(x[0], layer_0_2_val, width=bar_width, color=color_2_5, edgecolor="black", linewidth=1, label=legend_labels[5])
ax.bar(x[0], layer_3_10_val_2, bottom=layer_0_2_val, width=bar_width, color=color_4_6, edgecolor="black", linewidth=1, label=legend_labels[6])

# 오른쪽 막대 (Partial TEE Inference)
ax.bar(x[1], in_val, width=bar_width, color=color_1, edgecolor="black", linewidth=1, label=legend_labels[1])
ax.bar(x[1], infer_val, bottom=in_val, width=bar_width, color=color_2_5, edgecolor="black", linewidth=1, label=legend_labels[2])
ax.bar(x[1], out_val, bottom=in_val + infer_val, width=bar_width, color=color_3, edgecolor="black", linewidth=1, label=legend_labels[3])
ax.bar(x[1], layer_3_10_val, bottom=in_val + infer_val + out_val, width=bar_width, color=color_4_6, edgecolor="black", linewidth=1, label=legend_labels[4])

# 🔗 대응 구간 연결선 (Baseline ↔ Partial)
y_left_bottom = 0
y_left_top = layer_0_2_val
y_right_bottom = in_val
y_right_top = in_val + infer_val
x_left_edge = x[0] + bar_width / 2
x_right_edge = x[1] - bar_width / 2
ax.plot([x_left_edge, x_right_edge], [y_left_bottom, y_right_bottom],
        color="#000000", linewidth=2.5, linestyle="--", zorder=5)
ax.plot([x_left_edge, x_right_edge], [y_left_top, y_right_top],
        color="#000000", linewidth=2.5, linestyle="--", zorder=5)

# ==============================
# ⚙️ 스타일
ax.set_xticks(x)
ax.set_xticklabels(x_labels, color="black", fontsize=tick_fontsize)
ax.set_ylabel("Time (ms)", color="black", fontsize=label_fontsize)

for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1)

# ✅ 범례
handles, labels = ax.get_legend_handles_labels()
unique = dict(zip(labels, handles))
ax.legend(unique.values(), unique.keys(),
          loc="upper left",
          fontsize=legend_fontsize,
          frameon=True,
          edgecolor="black",
          facecolor="white")

plt.tight_layout()
plt.show()
